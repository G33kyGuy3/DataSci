# %% [markdown]
# Description: This program predicts employee attrition

# %%
# Import the libraries
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# Load the data
mydata = pd.read_excel("Employee Attrition Data.xlsx")

# %%
# Store daa into a data frame
df = pd.read_excel('Employee Attrition Data.xlsx')

# Print the first 7 rows of data
df.head(7)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41        No         Non-Travel        247  Research & Development
# 1   52       Yes      Travel_Rarely        266                   Sales
# 2   39        No  Travel_Frequently       1218  Research & Development
# 3   49        No  Travel_Frequently       1064  Research & Development
# 4   50        No      Travel_Rarely        797  Research & Development
# 5   40        No      Travel_Rarely        989  Research & Development
# 6   42        No         Non-Travel        495  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 7          1  Life Sciences              1            1035
# 1                 2          1      Marketing              1            1038
# 2                 1          1  Life Sciences              1             531
# 3                 2          1  Life Sciences              1            1941
# ...

# %%
# Get the number of rows and cols
df.shape
# Out:
# (1470, 35)

# %%
#Get the col data types
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
#Get a count of the empty values for each columns
df.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# Check for any missing/ null values in the data
df.isnull().values.any()
# Out:
# False

# %%
#View some statistics
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
#Get a count of the number of employees that stayed and left the company
df['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
#Visualize the the number of employees that stayed and left the company
sns.countplot(df['Attrition'])

# %%
# This is the percentage of we just guessed NO for attrition
(1233 - 237)/1233
# Out:
# 0.8077858880778589

# %%
#Show the number employees that left and stayed by age
import matplotlib.pyplot as plt
plt.subplots(figsize=(12,4))
sns.countplot(x='Age',hue='Attrition', data = df, palette = 'colorblind')

# %%
#Print all of the data types and their unique values
for column in df.columns:
  if df[column].dtype == object:
    print(str(column) + ' : '+ str(df[column].unique()))
    print(df[column].value_counts())
    print('____________________________________________________________________')
# Out:
# Attrition : ['No' 'Yes']
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
# ____________________________________________________________________
# BusinessTravel : ['Non-Travel' 'Travel_Rarely' 'Travel_Frequently']
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# ____________________________________________________________________
# Department : ['Research & Development' 'Sales' 'Human Resources']
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# ____________________________________________________________________
# EducationField : ['Life Sciences' 'Marketing' 'Medical' 'Technical Degree' 'Other'
#  'Human Resources']
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64
# ...

# %%
#Remove some useless columns
df = df.drop('Over18', axis= 1)
df = df.drop('EmployeeNumber', axis= 1)
df = df.drop('StandardHours', axis = 1)
df = df.drop('EmployeeCount', axis = 1)
df = df.drop('OverTime', axis = 1)

# %%
#Get the correlation
df.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# MonthlyIncome             0.497855   0.007707         -0.017014   0.094961
# MonthlyRate               0.028051  -0.032182          0.027473  -0.026084
# ...

# %%
#Visualize the correlation
plt.figure(figsize=(14,14))
sns.heatmap(df.corr(), annot=True, fmt = '.0%')

# %%
#Transform the data
#Transform non-numerical into numerical col
from sklearn.preprocessing import LabelEncoder

for column in df.columns:
  if df[column].dtype == np.number:
    continue
  df[column] = LabelEncoder().fit_transform(df[column])

# %%
#Create a new column
df['Age_Years'] = df['Age']

# %%
#Drop the age columnb
df = df.drop('Age', axis=1)

# %%
df
# Out:
#       Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0             0               0         94           1                 6
# 1             1               2        107           2                 1
# 2             0               1        697           1                 0
# 3             0               1        601           1                 1
# 4             0               2        443           1                 3
# ...         ...             ...        ...         ...               ...
# 1465          1               2        162           0                17
# 1466          0               2        824           1                 0
# 1467          1               2        190           1                24
# 1468          0               1        354           1                28
# 1469          0               2        744           1                 4
#
#       Education  EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# ...

# %%
#Split the data
X = df.iloc[:,1:df.shape[1]].values
Y = df.iloc[:, 0].values

# %%
#Split the data into 75% training and 25% testing
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.25, random_state = 0)

# %%
# Use the random forest classifer
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
forest.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
#Get the accuracy on the training dataset
forest.score(X_train, Y_train)
# Out:
# 0.9882032667876588

# %%
#Show the confusion matrix and accuracy score for the model on the test data 
from sklearn.metrics import confusion_matrix

cm1 = confusion_matrix(Y_train, forest.predict(X_train))

TN = cm1[0][0]
TP = cm1[1][1]
FN = cm1[1][0]
FP = cm1[0][1]

print(cm1)
print('Model Training Accuracy = {}'.format(( TP + TN) / (TP +TN + FN + FP) ))
print('Model Training Sensitivy = {}'.format((TP)/TP + FN))
print('Model Training Specificity = {}'.format((TN) / TN + FP))
# Out:
# [[929   0]
#  [ 13 160]]
# Model Training Accuracy = 0.9882032667876588
# Model Training Sensitivy = 14.0
# Model Training Specificity = 1.0

# %%
#Show the confusion matrix and accuracy score for the model on the test data 
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(Y_test, forest.predict(X_test))

TN = cm[0][0]
TP = cm[1][1]
FN = cm[1][0]
FP = cm[0][1]

print(cm)
print('Model Testing Accuracy = {}'.format(( TP + TN) / (TP +TN + FN + FP) ))
print('Model Testing Sensitivy = {}'.format((TP)/TP + FN))
print('Model Testing Specificity = {}'.format((TN) / TN + FP))
# Out:
# [[298   6]
#  [ 55   9]]
# Model Testing Accuracy = 0.8342391304347826
# Model Testing Sensitivy = 56.0
# Model Testing Specificity = 7.0
